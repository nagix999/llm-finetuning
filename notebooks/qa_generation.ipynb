# %%
import os
import re
import sys
import json
import glob
# from IPython.display import display, Markdown
sys.path.append("../")

from dotenv import load_dotenv
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.core.node_parser import SentenceWindowNodeParser, SentenceSplitter
from llama_index.core import PromptTemplate
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI
from llama_index.core.settings import Settings
import pandas as pd

from src.prompts import QA_GENERATION_PROMPT


load_dotenv()

JSON_PATTERN = r'\{[^}]*\}'

def read_file(file):
    with open(file, "r", encoding="utf-8") as f:
        contents = f.read()
        return contents

# %%
print(QA_GENERATION_PROMPT)
# Out:
# ## Role
# You are a Teacher/Professor. Your task is to setup ** Maximum 3 questions(0, 1, 2, 3) ** for an upcoming quiz/examination. The questions should be diverse in nature across the document. Restrict the questions to the context information provided.
#
# ## How to answer
# 1. Output in JSON format: [{"question": "", "A": "", "B": "", "C": "", "D": "", "answer": ""}]
# 2. Only write questions about the details of Dataiku or machine learning. If there are no questions to write, return an empty list (e.g., '[]').
# 3. All answers must be in capitalized English letters, such as A, B, C, D
# 4. Do not start with the markdown language, such as ```json, but with list opening brackets ([).
# 5. Don't write questions about things you think are unimportant or trivial. ** Ask questions as conservatively as possible**. Fewer questions are better.
#
# ## Examples
# ### Case1
# [{"question": "Which of the following is not a possible way to categorize statistical tests?", "A": "1-sample tests vs. 2-sample tests.", "B": "Descriptive tests vs. inferential tests.", "C": "Location tests vs. distribution tests.", "D": "Parametric tests vs. non-parametric tests.", "answer": "B"}]
#
# ### Case2
# []
#
# ### Case3
# [{"question": "Which of the following applications would involve the use of the API node? (Choose two.)", "A": "Generating a daily report of the predicted risks of loan default on a bank’s customer database.", "B": "Building a monthly dashboard of the evolution of e-commerce sales.", "C": "Predicting fraudulent transactions in real-time on a website.", "D": "Predicting the arrival time of an ongoing trip on a ride-share app like Uber.", "answer": "C, D"}]
#
# # context information
# {context}

# %%
dataiku_files = [file for file in glob.glob("../data/dataiku/**/*", recursive=True) if os.path.isfile(file)]

llm = OpenAI(model="gpt-4o", temperature=0.1)


qa_dataset = []

for file in dataiku_files:
    contents = read_file(file)
    response = llm.complete(QA_GENERATION_PROMPT.replace("{context}", contents))
    
    try:
        matches = re.findall(JSON_PATTERN, response.text)
        
        for json_data in matches:
            qa = json.loads(json_data)
            qa.update({"file": file})
            qa_dataset.append(qa)

        print(f"{len(matches)} QA generated from {file}")
    except Exception as e:
        print(e)
        print(f"Error occured when generating QA from {file} ")
        continue
# Out:
# 0 QA generated from ../data/dataiku\other.md
# 3 QA generated from ../data/dataiku\accessibility\index.md
# 1 QA generated from ../data/dataiku\api\index.md
# 3 QA generated from ../data/dataiku\api\js\index.md
# 1 QA generated from ../data/dataiku\api\scala\index.md
# 3 QA generated from ../data/dataiku\apinode\api-deployment-infrastructures.md
# 3 QA generated from ../data/dataiku\apinode\api-documentation.md
# 3 QA generated from ../data/dataiku\apinode\concepts.md
# 2 QA generated from ../data/dataiku\apinode\deploy-anywhere.md
# 3 QA generated from ../data/dataiku\apinode\endpoint-dataset-lookup.md
# 2 QA generated from ../data/dataiku\apinode\endpoint-mlflow.md
# 2 QA generated from ../data/dataiku\apinode\endpoint-python-function.md
# 3 QA generated from ../data/dataiku\apinode\endpoint-python-prediction.md
# 3 QA generated from ../data/dataiku\apinode\endpoint-r-function.md
# 3 QA generated from ../data/dataiku\apinode\endpoint-r-prediction.md
# 3 QA generated from ../data/dataiku\apinode\endpoint-sql-query.md
# 3 QA generated from ../data/dataiku\apinode\endpoint-std.md
# 1 QA generated from ../data/dataiku\apinode\endpoints.md
# 3 QA generated from ../data/dataiku\apinode\enrich-prediction-queries.md
# 3 QA generated from ../data/dataiku\apinode\first-service-apideployer.md
# 3 QA generated from ../data/dataiku\apinode\first-service-manual.md
# 3 QA generated from ../data/dataiku\apinode\index.md
# 1 QA generated from ../data/dataiku\apinode\installing-apinode.md
# 3 QA generated from ../data/dataiku\apinode\introduction.md
# 3 QA generated from ../data/dataiku\apinode\managing_versions.md
# 3 QA generated from ../data/dataiku\apinode\security.md
# 3 QA generated from ../data/dataiku\apinode\api\admin-api.md
# 3 QA generated from ../data/dataiku\apinode\api\endpoints-api.md
# 2 QA generated from ../data/dataiku\apinode\api\index.md
# 3 QA generated from ../data/dataiku\apinode\api\user-api.md
# 3 QA generated from ../data/dataiku\apinode\kubernetes\aks.md
# 3 QA generated from ../data/dataiku\apinode\kubernetes\eks.md
# 3 QA generated from ../data/dataiku\apinode\kubernetes\gke.md
# 2 QA generated from ../data/dataiku\apinode\kubernetes\index.md
# 2 QA generated from ../data/dataiku\apinode\kubernetes\minikube.md
# 2 QA generated from ../data/dataiku\apinode\kubernetes\setup.md
# 2 QA generated from ../data/dataiku\apinode\kubernetes\sql-connections.md
# 3 QA generated from ../data/dataiku\apinode\operations\cli-tool.md
# 3 QA generated from ../data/dataiku\apinode\operations\ha-deployment.md
# 2 QA generated from ../data/dataiku\apinode\operations\health-monitoring.md
# 2 QA generated from ../data/dataiku\apinode\operations\index.md
# 3 QA generated from ../data/dataiku\apinode\operations\logging-audit.md
# 3 QA generated from ../data/dataiku\applications\application-as-recipe.md
# 3 QA generated from ../data/dataiku\applications\index.md
# 3 QA generated from ../data/dataiku\applications\tiles.md
# 3 QA generated from ../data/dataiku\cloud\index.md
# 2 QA generated from ../data/dataiku\cloud\aws\index.md
# 3 QA generated from ../data/dataiku\cloud\aws\reference-architectures\eks-glue-athena.md
# 2 QA generated from ../data/dataiku\cloud\azure\index.md
# 3 QA generated from ../data/dataiku\cloud\azure\reference-architectures\azure-aks-adls.md
# 1 QA generated from ../data/dataiku\cloud\gcp\index.md
# 3 QA generated from ../data/dataiku\cloud\gcp\reference-architectures\gke-gcs.md
# 3 QA generated from ../data/dataiku\code-envs\automation.md
# 1 QA generated from ../data/dataiku\code-envs\base-packages.md
# 3 QA generated from ../data/dataiku\code-envs\conda.md
# 3 QA generated from ../data/dataiku\code-envs\custom-options.md
# 2 QA generated from ../data/dataiku\code-envs\index.md
# 2 QA generated from ../data/dataiku\code-envs\non-managed.md
# 3 QA generated from ../data/dataiku\code-envs\operations-python.md
# 2 QA generated from ../data/dataiku\code-envs\operations-r.md
# 1 QA generated from ../data/dataiku\code-envs\permissions.md
# 3 QA generated from ../data/dataiku\code-envs\plugins.md
# 3 QA generated from ../data/dataiku\code-envs\troubleshooting.md
# 0 QA generated from ../data/dataiku\code-reports\index.md
# 2 QA generated from ../data/dataiku\code-reports\rmarkdown.md
# 3 QA generated from ../data/dataiku\code-studios\code-studio-operations.md
# 0 QA generated from ../data/dataiku\code-studios\code-studio-project-exports-bundles.md
# 1 QA generated from ../data/dataiku\code-studios\code-studio-requirements.md
# 3 QA generated from ../data/dataiku\code-studios\code-studio-templates.md
# 3 QA generated from ../data/dataiku\code-studios\code-studios-as-webapps.md
# 3 QA generated from ../data/dataiku\code-studios\concepts.md
# 2 QA generated from ../data/dataiku\code-studios\index.md
# 1 QA generated from ../data/dataiku\code-studios\running.md
# 0 QA generated from ../data/dataiku\code-studios\code-studio-ides\index.md
# 3 QA generated from ../data/dataiku\code-studios\code-studio-ides\jupyterlab.md
# 2 QA generated from ../data/dataiku\code-studios\code-studio-ides\rstudio.md
# 2 QA generated from ../data/dataiku\code-studios\code-studio-ides\vs-code.md
# 3 QA generated from ../data/dataiku\code-studios\code-studio-webapps\gradio.md
# 0 QA generated from ../data/dataiku\code-studios\code-studio-webapps\index.md
# 3 QA generated from ../data/dataiku\code-studios\code-studio-webapps\streamlit.md
# 3 QA generated from ../data/dataiku\code-studios\code-studio-webapps\voila.md
# 2 QA generated from ../data/dataiku\code_recipes\code-explanations.md
# 3 QA generated from ../data/dataiku\code_recipes\common.md
# 3 QA generated from ../data/dataiku\code_recipes\hive.md
# 3 QA generated from ../data/dataiku\code_recipes\impala.md
# 1 QA generated from ../data/dataiku\code_recipes\index.md
# 2 QA generated from ../data/dataiku\code_recipes\pyspark.md
# 3 QA generated from ../data/dataiku\code_recipes\python.md
# 2 QA generated from ../data/dataiku\code_recipes\r.md
# 2 QA generated from ../data/dataiku\code_recipes\scala.md
# 2 QA generated from ../data/dataiku\code_recipes\shell.md
# 3 QA generated from ../data/dataiku\code_recipes\sparkr.md
# 3 QA generated from ../data/dataiku\code_recipes\sparksql.md
# 3 QA generated from ../data/dataiku\code_recipes\sql.md
# Unterminated string starting at: line 1 column 110 (char 109)
# Error occured when generating QA from ../data/dataiku\code_recipes\variables_expansion.md
# 3 QA generated from ../data/dataiku\collaboration\discussions.md
# 3 QA generated from ../data/dataiku\collaboration\git.md
# 3 QA generated from ../data/dataiku\collaboration\import-code-from-git.md
# 3 QA generated from ../data/dataiku\collaboration\import-notebooks-from-git.md
# 2 QA generated from ../data/dataiku\collaboration\index.md
# Unterminated string starting at: line 5 column 14 (char 234)
# Error occured when generating QA from ../data/dataiku\collaboration\markdown.md
# 3 QA generated from ../data/dataiku\collaboration\requests.md
# 2 QA generated from ../data/dataiku\collaboration\tags.md
# 3 QA generated from ../data/dataiku\collaboration\version-control.md
# 3 QA generated from ../data/dataiku\collaboration\wiki.md
# 3 QA generated from ../data/dataiku\concepts\index.md
# 0 QA generated from ../data/dataiku\concepts\homepage\getting-started-panel.md
# 0 QA generated from ../data/dataiku\concepts\homepage\index.md
# 3 QA generated from ../data/dataiku\concepts\homepage\project-folders.md
# 0 QA generated from ../data/dataiku\concepts\homepage\projects-folders-dashboards-wikis.md
# 0 QA generated from ../data/dataiku\concepts\homepage\recent-and-favorite-items.md
# 0 QA generated from ../data/dataiku\concepts\homepage\recommended-content-banner.md
# 0 QA generated from ../data/dataiku\concepts\homepage\section-order.md
# 2 QA generated from ../data/dataiku\concepts\projects\creating-through-macros.md
# Unterminated string starting at: line 4 column 14 (char 166)
# Error occured when generating QA from ../data/dataiku\concepts\projects\duplicate.md
# 2 QA generated from ../data/dataiku\concepts\projects\index.md
# 2 QA generated from ../data/dataiku\connecting\azure-blob.md
# 3 QA generated from ../data/dataiku\connecting\cassandra.md
# 2 QA generated from ../data/dataiku\connecting\clearing-nonmanaged.md
# 2 QA generated from ../data/dataiku\connecting\connections.md
# 1 QA generated from ../data/dataiku\connecting\data-transfer-cloud.md
# 3 QA generated from ../data/dataiku\connecting\dataset-plugins.md
# 1 QA generated from ../data/dataiku\connecting\editable-datasets.md
# 3 QA generated from ../data/dataiku\connecting\elasticsearch.md
# 3 QA generated from ../data/dataiku\connecting\files-in-folder.md
# 2 QA generated from ../data/dataiku\connecting\filesystem.md
# 3 QA generated from ../data/dataiku\connecting\ftp.md
# 3 QA generated from ../data/dataiku\connecting\gcs.md
# 3 QA generated from ../data/dataiku\connecting\googlesheets.md
# 0 QA generated from ../data/dataiku\connecting\hdfs.md
# 2 QA generated from ../data/dataiku\connecting\http-cached.md
# 2 QA generated from ../data/dataiku\connecting\http.md
# 3 QA generated from ../data/dataiku\connecting\index.md
# 2 QA generated from ../data/dataiku\connecting\internal-stats.md
# 1 QA generated from ../data/dataiku\connecting\kdbplus.md
# 3 QA generated from ../data/dataiku\connecting\managed_folders.md
# 2 QA generated from ../data/dataiku\connecting\metrics.md
# 2 QA generated from ../data/dataiku\connecting\ordering.md
# 3 QA generated from ../data/dataiku\connecting\pi-system.md
# 3 QA generated from ../data/dataiku\connecting\relocation.md
# 3 QA generated from ../data/dataiku\connecting\s3.md
# 2 QA generated from ../data/dataiku\connecting\scp-sftp.md
# 2 QA generated from ../data/dataiku\connecting\sharepoint-online.md
# 2 QA generated from ../data/dataiku\connecting\upload.md
# 2 QA generated from ../data/dataiku\connecting\excel\excel-templater.md
# 0 QA generated from ../data/dataiku\connecting\excel\index.md
# 3 QA generated from ../data/dataiku\connecting\formats\avro.md
# 3 QA generated from ../data/dataiku\connecting\formats\csv.md
# 2 QA generated from ../data/dataiku\connecting\formats\deltalake.md
# 0 QA generated from ../data/dataiku\connecting\formats\excel.md
# 0 QA generated from ../data/dataiku\connecting\formats\fixed-width.md
# 3 QA generated from ../data/dataiku\connecting\formats\index.md
# 2 QA generated from ../data/dataiku\connecting\formats\json.md
# 2 QA generated from ../data/dataiku\connecting\formats\orcfile.md
# 3 QA generated from ../data/dataiku\connecting\formats\parquet.md
# 3 QA generated from ../data/dataiku\connecting\formats\shapefile.md
# 3 QA generated from ../data/dataiku\connecting\formats\xml.md
# 2 QA generated from ../data/dataiku\connecting\nosql\mongo.md
# 3 QA generated from ../data/dataiku\connecting\sql\alloydb.md
# 3 QA generated from ../data/dataiku\connecting\sql\athena.md
# 3 QA generated from ../data/dataiku\connecting\sql\bigquery.md
# 0 QA generated from ../data/dataiku\connecting\sql\cloudsql.md
# 3 QA generated from ../data/dataiku\connecting\sql\databricks.md
# 2 QA generated from ../data/dataiku\connecting\sql\db2.md
# 2 QA generated from ../data/dataiku\connecting\sql\exasol.md
# 2 QA generated from ../data/dataiku\connecting\sql\greenplum.md
# 1 QA generated from ../data/dataiku\connecting\sql\index.md
# 3 QA generated from ../data/dataiku\connecting\sql\introduction.md
# 3 QA generated from ../data/dataiku\connecting\sql\mysql.md
# 1 QA generated from ../data/dataiku\connecting\sql\netezza.md
# 3 QA generated from ../data/dataiku\connecting\sql\oracle.md
# 3 QA generated from ../data/dataiku\connecting\sql\postgresql.md
# 3 QA generated from ../data/dataiku\connecting\sql\redshift.md
# 1 QA generated from ../data/dataiku\connecting\sql\saphana.md
# 3 QA generated from ../data/dataiku\connecting\sql\snowflake.md
# 3 QA generated from ../data/dataiku\connecting\sql\sqlserver.md
# 3 QA generated from ../data/dataiku\connecting\sql\synapse.md
# 3 QA generated from ../data/dataiku\connecting\sql\teradata.md
# 3 QA generated from ../data/dataiku\connecting\sql\vertica.md
# 2 QA generated from ../data/dataiku\containers\code-envs.md
# 3 QA generated from ../data/dataiku\containers\concepts.md
# 3 QA generated from ../data/dataiku\containers\containerized-dss-engine.md
# 3 QA generated from ../data/dataiku\containers\custom-base-images.md
# 3 QA generated from ../data/dataiku\containers\docker.md
# 3 QA generated from ../data/dataiku\containers\index.md
# 3 QA generated from ../data/dataiku\containers\managed-k8s-clusters.md
# 3 QA generated from ../data/dataiku\containers\namespaces.md
# 3 QA generated from ../data/dataiku\containers\setup-k8s.md
# 3 QA generated from ../data/dataiku\containers\troubleshooting.md
# 2 QA generated from ../data/dataiku\containers\unmanaged-k8s-clusters.md
# 2 QA generated from ../data/dataiku\containers\aks\index.md
# 3 QA generated from ../data/dataiku\containers\aks\managed.md
# 3 QA generated from ../data/dataiku\containers\aks\unmanaged.md
# 2 QA generated from ../data/dataiku\containers\dgxsystems\index.md
# 0 QA generated from ../data/dataiku\containers\eks\index.md
# 3 QA generated from ../data/dataiku\containers\eks\managed.md
# 3 QA generated from ../data/dataiku\containers\eks\unmanaged.md
# 0 QA generated from ../data/dataiku\containers\gke\index.md
# 3 QA generated from ../data/dataiku\containers\gke\managed.md
# 3 QA generated from ../data/dataiku\containers\gke\unmanaged.md
# 0 QA generated from ../data/dataiku\containers\openshift\index.md
# 3 QA generated from ../data/dataiku\dashboards\concepts.md
# 2 QA generated from ../data/dataiku\dashboards\display-settings.md
# 2 QA generated from ../data/dataiku\dashboards\exports.md
# 3 QA generated from ../data/dataiku\dashboards\filters.md
# 0 QA generated from ../data/dataiku\dashboards\index.md
# 3 QA generated from ../data/dataiku\dashboards\url-filters-query-param.md
# 3 QA generated from ../data/dataiku\dashboards\insights\chart.md
# 2 QA generated from ../data/dataiku\dashboards\insights\data-quality.md
# 0 QA generated from ../data/dataiku\dashboards\insights\dataset-table.md
# 3 QA generated from ../data/dataiku\dashboards\insights\index.md
# 3 QA generated from ../data/dataiku\dashboards\insights\jupyter-notebook.md
# 3 QA generated from ../data/dataiku\dashboards\insights\managed-folder.md
# 3 QA generated from ../data/dataiku\dashboards\insights\metric.md
# 3 QA generated from ../data/dataiku\dashboards\insights\model-report.md
# 2 QA generated from ../data/dataiku\dashboards\insights\scenario.md
# 3 QA generated from ../data/dataiku\dashboards\insights\webapp.md
# 0 QA generated from ../data/dataiku\dashboards\insights\wiki-article.md
# 2 QA generated from ../data/dataiku\data-catalog\datasets-indexed-tables.md
# 2 QA generated from ../data/dataiku\data-catalog\index.md
# 3 QA generated from ../data/dataiku\data-catalog\popular-datasets.md
# 2 QA generated from ../data/dataiku\data-catalog\data-collections\index.md
# 3 QA generated from ../data/dataiku\data-catalog\data-collections\managing.md
# 2 QA generated from ../data/dataiku\data-catalog\data-collections\permissions-and-dataset-visibility.md
# 2 QA generated from ../data/dataiku\data-catalog\data-collections\publish-to-data-collection.md
# 3 QA generated from ../data/dataiku\deployment\creating-bundles.md
# 3 QA generated from ../data/dataiku\deployment\deploying-bundles.md
# 3 QA generated from ../data/dataiku\deployment\index.md
# 3 QA generated from ../data/dataiku\deployment\manually-importing-bundles.md
# 3 QA generated from ../data/dataiku\deployment\project-deployment-infrastructures.md
# 3 QA generated from ../data/dataiku\deployment\setup.md
# 1 QA generated from ../data/dataiku\explore\analyze.md
# 2 QA generated from ../data/dataiku\explore\index.md
# 3 QA generated from ../data/dataiku\explore\sampling.md
# 3 QA generated from ../data/dataiku\flow\building-datasets.md
# Unterminated string starting at: line 3 column 14 (char 112)
# Error occured when generating QA from ../data/dataiku\flow\flow-document-generator.md
# 2 QA generated from ../data/dataiku\flow\flow-explanations.md
# 0 QA generated from ../data/dataiku\flow\folding.md
# 3 QA generated from ../data/dataiku\flow\graphics-export.md
# 3 QA generated from ../data/dataiku\flow\index.md
# 3 QA generated from ../data/dataiku\flow\limits.md
# 3 QA generated from ../data/dataiku\flow\visual-grammar.md
# 3 QA generated from ../data/dataiku\flow\zones.md
# 3 QA generated from ../data/dataiku\formula\index.md
# 1 QA generated from ../data/dataiku\generative-ai\answers.md
# 0 QA generated from ../data/dataiku\generative-ai\api.md
# 3 QA generated from ../data/dataiku\generative-ai\code-assistant.md
# 3 QA generated from ../data/dataiku\generative-ai\huggingface-models.md
# 3 QA generated from ../data/dataiku\generative-ai\index.md
# 3 QA generated from ../data/dataiku\generative-ai\introduction.md
# 3 QA generated from ../data/dataiku\generative-ai\llm-connections.md
# 3 QA generated from ../data/dataiku\generative-ai\model-cache.md
# 3 QA generated from ../data/dataiku\generative-ai\model-fine-tuning.md
# 3 QA generated from ../data/dataiku\generative-ai\multimodal.md
# 3 QA generated from ../data/dataiku\generative-ai\pii-detection.md
# 2 QA generated from ../data/dataiku\generative-ai\prompt-studio.md
# 3 QA generated from ../data/dataiku\generative-ai\rag.md
# 2 QA generated from ../data/dataiku\geographic\data.md
# 3 QA generated from ../data/dataiku\geographic\geocoding.md
# 1 QA generated from ../data/dataiku\geographic\geoformula.md
# 2 QA generated from ../data/dataiku\geographic\geojoin.md
# 3 QA generated from ../data/dataiku\geographic\georouting.md
# 2 QA generated from ../data/dataiku\geographic\index.md
# 3 QA generated from ../data/dataiku\geographic\preparation.md
# 2 QA generated from ../data/dataiku\geographic\types.md
# 1 QA generated from ../data/dataiku\geographic\visualization.md
# 3 QA generated from ../data/dataiku\governance\definitions.md
# 3 QA generated from ../data/dataiku\governance\governance-features.md
# 3 QA generated from ../data/dataiku\governance\index.md
# 3 QA generated from ../data/dataiku\governance\navigation-item.md
# 3 QA generated from ../data/dataiku\governance\setup.md
# 3 QA generated from ../data/dataiku\governance\types-govern-items.md
# 1 QA generated from ../data/dataiku\governance\publicapi\features.md
# 2 QA generated from ../data/dataiku\governance\publicapi\index.md
# 2 QA generated from ../data/dataiku\governance\publicapi\keys.md
# 3 QA generated from ../data/dataiku\governance\publicapi\rest.md
# 3 QA generated from ../data/dataiku\hadoop\hadoop-fs-connections.md
# 3 QA generated from ../data/dataiku\hadoop\hive-dataset.md
# 3 QA generated from ../data/dataiku\hadoop\hive.md
# 3 QA generated from ../data/dataiku\hadoop\impala.md
# 3 QA generated from ../data/dataiku\hadoop\index.md
# 3 QA generated from ../data/dataiku\hadoop\installation.md
# 3 QA generated from ../data/dataiku\hadoop\multi-clusters.md
# 3 QA generated from ../data/dataiku\hadoop\secure-clusters.md
# 3 QA generated from ../data/dataiku\hadoop\spark.md
# 2 QA generated from ../data/dataiku\hadoop\tdch.md
# 0 QA generated from ../data/dataiku\hadoop\user-isolation.md
# 3 QA generated from ../data/dataiku\hadoop\distributions\cdp.md
# 0 QA generated from ../data/dataiku\hadoop\distributions\index.md
# 2 QA generated from ../data/dataiku\installation\index.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-aws\concepts.md
# 2 QA generated from ../data/dataiku\installation\cloudstacks-aws\dss-backup.md
# 0 QA generated from ../data/dataiku\installation\cloudstacks-aws\dss-upgrade.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-aws\fm-upgrade-cf.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-aws\guided-setup-new-vpc-elastic-compute.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-aws\index.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-aws\instances.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-aws\sso.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-aws\templates-actions.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-aws\tenant-settings.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-aws\virtual-networks.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-azure\concepts.md
# 2 QA generated from ../data/dataiku\installation\cloudstacks-azure\dss-backup.md
# 2 QA generated from ../data/dataiku\installation\cloudstacks-azure\dss-upgrade.md
# 2 QA generated from ../data/dataiku\installation\cloudstacks-azure\fm-upgrade.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-azure\guided-setup-new-vnet-elastic-compute.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-azure\index.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-azure\instances.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-azure\sso.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-azure\templates-actions.md
# 2 QA generated from ../data/dataiku\installation\cloudstacks-azure\tenant-settings.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-azure\virtual-networks.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-gcp\concepts.md
# 2 QA generated from ../data/dataiku\installation\cloudstacks-gcp\dss-backup.md
# 0 QA generated from ../data/dataiku\installation\cloudstacks-gcp\dss-upgrade.md
# 2 QA generated from ../data/dataiku\installation\cloudstacks-gcp\fm-upgrade.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-gcp\guided-setup-new-vpc-elastic-compute.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-gcp\index.md
# 2 QA generated from ../data/dataiku\installation\cloudstacks-gcp\instances.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-gcp\sso.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-gcp\templates-actions.md
# 2 QA generated from ../data/dataiku\installation\cloudstacks-gcp\tenant-settings.md
# 3 QA generated from ../data/dataiku\installation\cloudstacks-gcp\virtual-networks.md
# 3 QA generated from ../data/dataiku\installation\custom\advanced-customization.md
# 3 QA generated from ../data/dataiku\installation\custom\advanced-java-customization.md
# 2 QA generated from ../data/dataiku\installation\custom\api-node.md
# 2 QA generated from ../data/dataiku\installation\custom\automation-node.md
# 2 QA generated from ../data/dataiku\installation\custom\deployer-node.md
# 3 QA generated from ../data/dataiku\installation\custom\govern-node.md
# 3 QA generated from ../data/dataiku\installation\custom\graphics-export.md
# 2 QA generated from ../data/dataiku\installation\custom\hadoop-spark.md
# 1 QA generated from ../data/dataiku\installation\custom\index.md
# 3 QA generated from ../data/dataiku\installation\custom\initial-install.md
# 2 QA generated from ../data/dataiku\installation\custom\jdbc.md
# 2 QA generated from ../data/dataiku\installation\custom\migrations.md
# 3 QA generated from ../data/dataiku\installation\custom\python.md
# 3 QA generated from ../data/dataiku\installation\custom\r.md
# 3 QA generated from ../data/dataiku\installation\custom\requirements.md
# 2 QA generated from ../data/dataiku\installation\custom\reverse-proxy.md
# 3 QA generated from ../data/dataiku\installation\custom\upgrade.md
# 3 QA generated from ../data/dataiku\installation\other\aws.md
# 3 QA generated from ../data/dataiku\installation\other\azure.md
# 0 QA generated from ../data/dataiku\installation\other\container.md
# 3 QA generated from ../data/dataiku\installation\other\gcp.md
# 0 QA generated from ../data/dataiku\installation\other\index.md
# 3 QA generated from ../data/dataiku\installation\other\osx.md
# 3 QA generated from ../data/dataiku\installation\other\vm.md
# 3 QA generated from ../data/dataiku\installation\other\windows.md
# 3 QA generated from ../data/dataiku\machine-learning\advanced-optimization.md
# 3 QA generated from ../data/dataiku\machine-learning\auto-ml.md
# 1 QA generated from ../data/dataiku\machine-learning\custom-models.md
# 3 QA generated from ../data/dataiku\machine-learning\diagnostics.md
# 2 QA generated from ../data/dataiku\machine-learning\ensembles.md
# 3 QA generated from ../data/dataiku\machine-learning\index.md
# 3 QA generated from ../data/dataiku\machine-learning\labeling.md
# 3 QA generated from ../data/dataiku\machine-learning\model-document-generator.md
# 3 QA generated from ../data/dataiku\machine-learning\models-export.md
# 2 QA generated from ../data/dataiku\machine-learning\models-lifecycle.md
# 2 QA generated from ../data/dataiku\machine-learning\partitioned.md
# 3 QA generated from ../data/dataiku\machine-learning\scoring-engines.md
# 3 QA generated from ../data/dataiku\machine-learning\task-reuse.md
# 3 QA generated from ../data/dataiku\machine-learning\algorithms\in-memory-python.md
# 2 QA generated from ../data/dataiku\machine-learning\algorithms\index.md
# 3 QA generated from ../data/dataiku\machine-learning\algorithms\mllib.md
# 3 QA generated from ../data/dataiku\machine-learning\causal-prediction\causal-prediction-algorithms.md
# 2 QA generated from ../data/dataiku\machine-learning\causal-prediction\evaluation.md
# 3 QA generated from ../data/dataiku\machine-learning\causal-prediction\index.md
# 3 QA generated from ../data/dataiku\machine-learning\causal-prediction\introduction.md
# 3 QA generated from ../data/dataiku\machine-learning\causal-prediction\results.md
# 3 QA generated from ../data/dataiku\machine-learning\causal-prediction\scoring.md
# 3 QA generated from ../data/dataiku\machine-learning\causal-prediction\settings.md
# 3 QA generated from ../data/dataiku\machine-learning\computer-vision\architecture.md
# 2 QA generated from ../data/dataiku\machine-learning\computer-vision\data-augmentation.md
# 1 QA generated from ../data/dataiku\machine-learning\computer-vision\endpoints-api.md
# 3 QA generated from ../data/dataiku\machine-learning\computer-vision\evaluation-metrics.md
# 3 QA generated from ../data/dataiku\machine-learning\computer-vision\first-model.md
# 3 QA generated from ../data/dataiku\machine-learning\computer-vision\index.md
# 3 QA generated from ../data/dataiku\machine-learning\computer-vision\inputs.md
# 2 QA generated from ../data/dataiku\machine-learning\computer-vision\introduction.md
# 3 QA generated from ../data/dataiku\machine-learning\computer-vision\performance-assessment.md
# 3 QA generated from ../data/dataiku\machine-learning\computer-vision\runtime-gpu.md
# 3 QA generated from ../data/dataiku\machine-learning\deep-learning\advanced.md
# 3 QA generated from ../data/dataiku\machine-learning\deep-learning\architecture.md
# 2 QA generated from ../data/dataiku\machine-learning\deep-learning\first-model.md
# 2 QA generated from ../data/dataiku\machine-learning\deep-learning\images.md
# 3 QA generated from ../data/dataiku\machine-learning\deep-learning\index.md
# 2 QA generated from ../data/dataiku\machine-learning\deep-learning\inputs.md
# 3 QA generated from ../data/dataiku\machine-learning\deep-learning\introduction.md
# 3 QA generated from ../data/dataiku\machine-learning\deep-learning\runtime-gpu.md
# 1 QA generated from ../data/dataiku\machine-learning\deep-learning\text.md
# 0 QA generated from ../data/dataiku\machine-learning\deep-learning\training.md
# 3 QA generated from ../data/dataiku\machine-learning\deep-learning\troubleshooting.md
# 3 QA generated from ../data/dataiku\machine-learning\features-handling\categorical.md
# 3 QA generated from ../data/dataiku\machine-learning\features-handling\custom.md
# 2 QA generated from ../data/dataiku\machine-learning\features-handling\images.md
# 3 QA generated from ../data/dataiku\machine-learning\features-handling\index.md
# 3 QA generated from ../data/dataiku\machine-learning\features-handling\numerical.md
# 3 QA generated from ../data/dataiku\machine-learning\features-handling\roles-and-types.md
# 3 QA generated from ../data/dataiku\machine-learning\features-handling\text.md
# 3 QA generated from ../data/dataiku\machine-learning\features-handling\vectors.md
# 3 QA generated from ../data/dataiku\machine-learning\supervised\explanations.md
# 3 QA generated from ../data/dataiku\machine-learning\supervised\index.md
# 3 QA generated from ../data/dataiku\machine-learning\supervised\interactive-scoring.md
# 3 QA generated from ../data/dataiku\machine-learning\supervised\ml-assertions.md
# 3 QA generated from ../data/dataiku\machine-learning\supervised\model-error-analysis.md
# 3 QA generated from ../data/dataiku\machine-learning\supervised\model-exploration.md
# 3 QA generated from ../data/dataiku\machine-learning\supervised\model-fairness-report.md
# 2 QA generated from ../data/dataiku\machine-learning\supervised\prediction-intervals.md
# 3 QA generated from ../data/dataiku\machine-learning\supervised\prediction-overrides.md
# 3 QA generated from ../data/dataiku\machine-learning\supervised\results.md
# 3 QA generated from ../data/dataiku\machine-learning\supervised\settings.md
# 3 QA generated from ../data/dataiku\machine-learning\time-series-forecasting\evaluation.md
# 3 QA generated from ../data/dataiku\machine-learning\time-series-forecasting\index.md
# 2 QA generated from ../data/dataiku\machine-learning\time-series-forecasting\introduction.md
# 3 QA generated from ../data/dataiku\machine-learning\time-series-forecasting\results.md
# 2 QA generated from ../data/dataiku\machine-learning\time-series-forecasting\runtime-gpu.md
# 2 QA generated from ../data/dataiku\machine-learning\time-series-forecasting\scoring.md
# 3 QA generated from ../data/dataiku\machine-learning\time-series-forecasting\settings.md
# 2 QA generated from ../data/dataiku\machine-learning\unsupervised\index.md
# 3 QA generated from ../data/dataiku\machine-learning\unsupervised\settings.md
# 3 QA generated from ../data/dataiku\metastore\index.md
# 3 QA generated from ../data/dataiku\metrics-check-data-quality\checks.md
# 3 QA generated from ../data/dataiku\metrics-check-data-quality\custom_metrics_and_checks.md
# 3 QA generated from ../data/dataiku\metrics-check-data-quality\data-quality-rules.md
# 3 QA generated from ../data/dataiku\metrics-check-data-quality\data-quality-templates.md
# 3 QA generated from ../data/dataiku\metrics-check-data-quality\index.md
# 3 QA generated from ../data/dataiku\metrics-check-data-quality\metrics.md
# 2 QA generated from ../data/dataiku\mlops\index.md
# 3 QA generated from ../data/dataiku\mlops\drift-analysis\index.md
# 3 QA generated from ../data/dataiku\mlops\drift-analysis\input-data-drift.md
# 1 QA generated from ../data/dataiku\mlops\drift-analysis\performance-drift.md
# 3 QA generated from ../data/dataiku\mlops\drift-analysis\prediction-drift.md
# 1 QA generated from ../data/dataiku\mlops\drift-analysis\reference.md
# 3 QA generated from ../data/dataiku\mlops\drift-analysis\sampling.md
# 3 QA generated from ../data/dataiku\mlops\experiment-tracking\concepts.md
# 2 QA generated from ../data/dataiku\mlops\experiment-tracking\deploying.md
# 3 QA generated from ../data/dataiku\mlops\experiment-tracking\extensions.md
# 2 QA generated from ../data/dataiku\mlops\experiment-tracking\index.md
# 3 QA generated from ../data/dataiku\mlops\experiment-tracking\tracking.md
# 3 QA generated from ../data/dataiku\mlops\experiment-tracking\viewing.md
# 3 QA generated from ../data/dataiku\mlops\external-models\index.md
# 3 QA generated from ../data/dataiku\mlops\external-models\input-output-formats.md
# 3 QA generated from ../data/dataiku\mlops\feature-store\index.md
# 3 QA generated from ../data/dataiku\mlops\mlflow-models\importing.md
# 2 QA generated from ../data/dataiku\mlops\mlflow-models\index.md
# 2 QA generated from ../data/dataiku\mlops\mlflow-models\limitations.md
# 3 QA generated from ../data/dataiku\mlops\mlflow-models\training.md
# 2 QA generated from ../data/dataiku\mlops\mlflow-models\using.md
# 3 QA generated from ../data/dataiku\mlops\model-comparisons\index.md
# 3 QA generated from ../data/dataiku\mlops\model-evaluations\analyzing-evaluations.md
# 2 QA generated from ../data/dataiku\mlops\model-evaluations\automating.md
# 3 QA generated from ../data/dataiku\mlops\model-evaluations\concepts.md
# 2 QA generated from ../data/dataiku\mlops\model-evaluations\dss-models.md
# 3 QA generated from ../data/dataiku\mlops\model-evaluations\external-models.md
# 3 QA generated from ../data/dataiku\mlops\model-evaluations\index.md
# 2 QA generated from ../data/dataiku\mlops\unified-monitoring\accessing-unified-monitoring.md
# 3 QA generated from ../data/dataiku\mlops\unified-monitoring\api-endpoints.md
# 3 QA generated from ../data/dataiku\mlops\unified-monitoring\dataiku-projects.md
# 1 QA generated from ../data/dataiku\mlops\unified-monitoring\index.md
# 2 QA generated from ../data/dataiku\mlops\unified-monitoring\model-status.md
# 0 QA generated from ../data/dataiku\mlops\unified-monitoring\synchronization-interval.md
# 0 QA generated from ../data/dataiku\mlops\unified-monitoring\unified-monitoring-settings.md
# 3 QA generated from ../data/dataiku\nlp\aws-apis.md
# 2 QA generated from ../data/dataiku\nlp\azure-apis.md
# 1 QA generated from ../data/dataiku\nlp\crowlingo-apis.md
# 0 QA generated from ../data/dataiku\nlp\deepl-api.md
# 3 QA generated from ../data/dataiku\nlp\embedding.md
# 2 QA generated from ../data/dataiku\nlp\google-apis.md
# 3 QA generated from ../data/dataiku\nlp\index.md
# 2 QA generated from ../data/dataiku\nlp\key-phrase-extraction.md
# 2 QA generated from ../data/dataiku\nlp\language-detection.md
# 2 QA generated from ../data/dataiku\nlp\meaningcloud-apis.md
# 3 QA generated from ../data/dataiku\nlp\named-entities.md
# 2 QA generated from ../data/dataiku\nlp\ocr.md
# 3 QA generated from ../data/dataiku\nlp\ontology-tagging.md
# 2 QA generated from ../data/dataiku\nlp\openai-gpt.md
# 2 QA generated from ../data/dataiku\nlp\sentiment-analysis.md
# 2 QA generated from ../data/dataiku\nlp\speech-to-text.md
# 2 QA generated from ../data/dataiku\nlp\spell-checking.md
# 3 QA generated from ../data/dataiku\nlp\summarization.md
# 3 QA generated from ../data/dataiku\nlp\text-cleaning.md
# 3 QA generated from ../data/dataiku\nlp\text-extraction.md
# 1 QA generated from ../data/dataiku\nlp\text-in-ml.md
# 3 QA generated from ../data/dataiku\nlp\translation.md
# 3 QA generated from ../data/dataiku\notebooks\containerized-notebooks.md
# 3 QA generated from ../data/dataiku\notebooks\index.md
# 3 QA generated from ../data/dataiku\notebooks\jupyter-nbextensions.md
# 3 QA generated from ../data/dataiku\notebooks\predefined-notebooks.md
# 3 QA generated from ../data/dataiku\notebooks\python.md
# 3 QA generated from ../data/dataiku\notebooks\search-notebook.md
# 3 QA generated from ../data/dataiku\notebooks\sql-notebook.md
# 3 QA generated from ../data/dataiku\operations\backups.md
# 0 QA generated from ../data/dataiku\operations\cgroups.md
# 3 QA generated from ../data/dataiku\operations\compute-resource-usage-reporting.md
# 3 QA generated from ../data/dataiku\operations\datadir.md
# 3 QA generated from ../data/dataiku\operations\disk-usage.md
# 3 QA generated from ../data/dataiku\operations\dsscli.md
# 3 QA generated from ../data/dataiku\operations\index.md
# 2 QA generated from ../data/dataiku\operations\license.md
# 3 QA generated from ../data/dataiku\operations\logging.md
# 3 QA generated from ../data/dataiku\operations\macros.md
# 3 QA generated from ../data/dataiku\operations\memory.md
# 2 QA generated from ../data/dataiku\operations\monitoring.md
# 3 QA generated from ../data/dataiku\operations\processes.md
# 2 QA generated from ../data/dataiku\operations\proxies.md
# 3 QA generated from ../data/dataiku\operations\runtime-databases.md
# 3 QA generated from ../data/dataiku\operations\audit-trail\apinode.md
# 2 QA generated from ../data/dataiku\operations\audit-trail\centralization-and-dispatch.md
# 3 QA generated from ../data/dataiku\operations\audit-trail\data.md
# 2 QA generated from ../data/dataiku\operations\audit-trail\dataikucloud.md
# 0 QA generated from ../data/dataiku\operations\audit-trail\default-storage.md
# 3 QA generated from ../data/dataiku\operations\audit-trail\eventserver.md
# 3 QA generated from ../data/dataiku\operations\audit-trail\index.md
# 0 QA generated from ../data/dataiku\operations\audit-trail\viewing-in-dss.md
# 2 QA generated from ../data/dataiku\other_recipes\distinct.md
# 3 QA generated from ../data/dataiku\other_recipes\download.md
# 3 QA generated from ../data/dataiku\other_recipes\fuzzy-join.md
# 3 QA generated from ../data/dataiku\other_recipes\generate-features.md
# 3 QA generated from ../data/dataiku\other_recipes\geojoin.md
# 2 QA generated from ../data/dataiku\other_recipes\grouping.md
# 3 QA generated from ../data/dataiku\other_recipes\index.md
# 3 QA generated from ../data/dataiku\other_recipes\join.md
# 2 QA generated from ../data/dataiku\other_recipes\list-folder-contents.md
# 3 QA generated from ../data/dataiku\other_recipes\pivot.md
# 2 QA generated from ../data/dataiku\other_recipes\prepare.md
# 3 QA generated from ../data/dataiku\other_recipes\push-to-editable.md
# 3 QA generated from ../data/dataiku\other_recipes\sampling.md
# 2 QA generated from ../data/dataiku\other_recipes\sort.md
# 1 QA generated from ../data/dataiku\other_recipes\split.md
# 0 QA generated from ../data/dataiku\other_recipes\stack.md
# 3 QA generated from ../data/dataiku\other_recipes\sync.md
# 3 QA generated from ../data/dataiku\other_recipes\topn.md
# 2 QA generated from ../data/dataiku\other_recipes\window.md
# 3 QA generated from ../data/dataiku\partitions\dependencies.md
# 2 QA generated from ../data/dataiku\partitions\fs_datasets.md
# 2 QA generated from ../data/dataiku\partitions\hive.md
# 3 QA generated from ../data/dataiku\partitions\identifiers.md
# 2 QA generated from ../data/dataiku\partitions\index.md
# 1 QA generated from ../data/dataiku\partitions\models.md
# 3 QA generated from ../data/dataiku\partitions\recipes.md
# 2 QA generated from ../data/dataiku\partitions\sql_datasets.md
# 3 QA generated from ../data/dataiku\partitions\sql_recipes.md
# Unterminated string starting at: line 3 column 14 (char 87)
# Error occured when generating QA from ../data/dataiku\partitions\variables.md
# 1 QA generated from ../data/dataiku\plugins\index.md
# 0 QA generated from ../data/dataiku\plugins\installed.md
# 2 QA generated from ../data/dataiku\plugins\installing.md
# 3 QA generated from ../data/dataiku\plugins\reference\git-editor.md
# 2 QA generated from ../data/dataiku\plugins\reference\index.md
# 3 QA generated from ../data/dataiku\plugins\reference\other.md
# 3 QA generated from ../data/dataiku\plugins\reference\params.md
# 3 QA generated from ../data/dataiku\plugins\reference\plugins-components.md
# 0 QA generated from ../data/dataiku\preparation\copy-steps.md
# 3 QA generated from ../data/dataiku\preparation\dates.md
# 3 QA generated from ../data/dataiku\preparation\engines.md
# 3 QA generated from ../data/dataiku\preparation\filter-flag.md
# 3 QA generated from ../data/dataiku\preparation\geographic.md
# 3 QA generated from ../data/dataiku\preparation\index.md
# 3 QA generated from ../data/dataiku\preparation\reshaping.md
# 0 QA generated from ../data/dataiku\preparation\sampling.md
# 0 QA generated from ../data/dataiku\preparation\processors\array-extract.md
# 0 QA generated from ../data/dataiku\preparation\processors\array-fold.md
# 0 QA generated from ../data/dataiku\preparation\processors\array-sort.md
# 0 QA generated from ../data/dataiku\preparation\processors\arrays-concat.md
# 1 QA generated from ../data/dataiku\preparation\processors\binner.md
# 0 QA generated from ../data/dataiku\preparation\processors\change-crs.md
# 0 QA generated from ../data/dataiku\preparation\processors\column-copy.md
# 3 QA generated from ../data/dataiku\preparation\processors\column-pseudonymization.md
# 0 QA generated from ../data/dataiku\preparation\processors\column-rename.md
# 0 QA generated from ../data/dataiku\preparation\processors\columns-concat.md
# 0 QA generated from ../data/dataiku\preparation\processors\columns-select.md
# 2 QA generated from ../data/dataiku\preparation\processors\count-matches.md
# 3 QA generated from ../data/dataiku\preparation\processors\create-if-then-else.md
# 1 QA generated from ../data/dataiku\preparation\processors\currency-converter.md
# 0 QA generated from ../data/dataiku\preparation\processors\currency-splitter.md
# 2 QA generated from ../data/dataiku\preparation\processors\date-components-extract.md
# 0 QA generated from ../data/dataiku\preparation\processors\date-difference.md
# 2 QA generated from ../data/dataiku\preparation\processors\date-formatter.md
# 2 QA generated from ../data/dataiku\preparation\processors\date-parser.md
# 0 QA generated from ../data/dataiku\preparation\processors\email-split.md
# 0 QA generated from ../data/dataiku\preparation\processors\enrich-french-departement.md
# 2 QA generated from ../data/dataiku\preparation\processors\enrich-french-postcode.md
# 0 QA generated from ../data/dataiku\preparation\processors\enrich-with-build-context.md
# 0 QA generated from ../data/dataiku\preparation\processors\enrich-with-record-context.md
# 3 QA generated from ../data/dataiku\preparation\processors\extract-ngrams.md
# 2 QA generated from ../data/dataiku\preparation\processors\extract-numbers.md
# 0 QA generated from ../data/dataiku\preparation\processors\fill-column.md
# 2 QA generated from ../data/dataiku\preparation\processors\fill-empty-with-computed-value.md
# 1 QA generated from ../data/dataiku\preparation\processors\fill-empty.md
# 1 QA generated from ../data/dataiku\preparation\processors\filter-on-date.md
# 0 QA generated from ../data/dataiku\preparation\processors\filter-on-formula.md
# 2 QA generated from ../data/dataiku\preparation\processors\filter-on-meaning.md
# 1 QA generated from ../data/dataiku\preparation\processors\filter-on-range.md
# 3 QA generated from ../data/dataiku\preparation\processors\filter-on-value.md
# 2 QA generated from ../data/dataiku\preparation\processors\find-replace.md
# 2 QA generated from ../data/dataiku\preparation\processors\flag-on-date.md
# 2 QA generated from ../data/dataiku\preparation\processors\flag-on-formula.md
# 1 QA generated from ../data/dataiku\preparation\processors\flag-on-meaning.md
# 3 QA generated from ../data/dataiku\preparation\processors\flag-on-range.md
# 0 QA generated from ../data/dataiku\preparation\processors\flag-on-value.md
# 1 QA generated from ../data/dataiku\preparation\processors\fold-columns-by-name.md
# 3 QA generated from ../data/dataiku\preparation\processors\fold-columns-by-pattern.md
# 0 QA generated from ../data/dataiku\preparation\processors\fold-object.md
# 3 QA generated from ../data/dataiku\preparation\processors\formula.md
# 3 QA generated from ../data/dataiku\preparation\processors\fuzzy-join.md
# 0 QA generated from ../data/dataiku\preparation\processors\generate-big-data.md
# 3 QA generated from ../data/dataiku\preparation\processors\geo-distance.md
# 1 QA generated from ../data/dataiku\preparation\processors\geo-info-extractor.md
# 3 QA generated from ../data/dataiku\preparation\processors\geo-join.md
# 0 QA generated from ../data/dataiku\preparation\processors\geoip.md
# 2 QA generated from ../data/dataiku\preparation\processors\geopoint-buffer.md
# 1 QA generated from ../data/dataiku\preparation\processors\geopoint-create.md
# 1 QA generated from ../data/dataiku\preparation\processors\geopoint-extract.md
# Unterminated string starting at: line 3 column 14 (char 134)
# Error occured when generating QA from ../data/dataiku\preparation\processors\grok.md
# 2 QA generated from ../data/dataiku\preparation\processors\holidays-computer.md
# 3 QA generated from ../data/dataiku\preparation\processors\index.md
# 2 QA generated from ../data/dataiku\preparation\processors\invalid-split.md
# 3 QA generated from ../data/dataiku\preparation\processors\join.md
# Unterminated string starting at: line 2 column 21 (char 22)
# Error occured when generating QA from ../data/dataiku\preparation\processors\jsonpath.md
# 1 QA generated from ../data/dataiku\preparation\processors\long-tail.md
# 2 QA generated from ../data/dataiku\preparation\processors\mean.md
# 0 QA generated from ../data/dataiku\preparation\processors\meaning-translate.md
# 0 QA generated from ../data/dataiku\preparation\processors\measure-normalize.md
# 0 QA generated from ../data/dataiku\preparation\processors\merge-long-tail-values.md
# 0 QA generated from ../data/dataiku\preparation\processors\move-columns.md
# 0 QA generated from ../data/dataiku\preparation\processors\negate.md
# 0 QA generated from ../data/dataiku\preparation\processors\number-clipping.md
# 1 QA generated from ../data/dataiku\preparation\processors\numerical-combinations.md
# 0 QA generated from ../data/dataiku\preparation\processors\numerical-format-convert.md
# 0 QA generated from ../data/dataiku\preparation\processors\object-nest.md
# 2 QA generated from ../data/dataiku\preparation\processors\object-unnest-json.md
# 2 QA generated from ../data/dataiku\preparation\processors\pattern-extract.md
# 0 QA generated from ../data/dataiku\preparation\processors\pivot.md
# 2 QA generated from ../data/dataiku\preparation\processors\python-custom.md
# 2 QA generated from ../data/dataiku\preparation\processors\querystring-split.md
# 1 QA generated from ../data/dataiku\preparation\processors\remove-empty.md
# 0 QA generated from ../data/dataiku\preparation\processors\round.md
# 0 QA generated from ../data/dataiku\preparation\processors\simplify-text.md
# 0 QA generated from ../data/dataiku\preparation\processors\split-fold.md
# 2 QA generated from ../data/dataiku\preparation\processors\split-into-chunks.md
# 1 QA generated from ../data/dataiku\preparation\processors\split-unfold.md
# 0 QA generated from ../data/dataiku\preparation\processors\split.md
# 1 QA generated from ../data/dataiku\preparation\processors\string-transform.md
# 1 QA generated from ../data/dataiku\preparation\processors\switch-case.md
# 2 QA generated from ../data/dataiku\preparation\processors\tokenizer.md
# 0 QA generated from ../data/dataiku\preparation\processors\transpose.md
# 3 QA generated from ../data/dataiku\preparation\processors\triggered-unfold.md
# 2 QA generated from ../data/dataiku\preparation\processors\unfold-array.md
# 2 QA generated from ../data/dataiku\preparation\processors\unfold.md
# 0 QA generated from ../data/dataiku\preparation\processors\unixtimestamp-parser.md
# 0 QA generated from ../data/dataiku\preparation\processors\up-down-fill.md
# 0 QA generated from ../data/dataiku\preparation\processors\url-split.md
# 2 QA generated from ../data/dataiku\preparation\processors\user-agent.md
# 1 QA generated from ../data/dataiku\preparation\processors\visitor-id.md
# Unterminated string starting at: line 3 column 14 (char 175)
# Error occured when generating QA from ../data/dataiku\preparation\processors\zip-arrays.md
# 3 QA generated from ../data/dataiku\publicapi\features.md
# 2 QA generated from ../data/dataiku\publicapi\index.md
# 3 QA generated from ../data/dataiku\publicapi\keys.md
# 3 QA generated from ../data/dataiku\publicapi\rest.md
# 3 QA generated from ../data/dataiku\python\bokeh.md
# 0 QA generated from ../data/dataiku\python\ggplot.md
# 3 QA generated from ../data/dataiku\python\index.md
# 0 QA generated from ../data/dataiku\python\ipywidgets.md
# 3 QA generated from ../data/dataiku\python\matplotlib.md
# 2 QA generated from ../data/dataiku\python\packages.md
# 3 QA generated from ../data/dataiku\python\plotly.md
# 3 QA generated from ../data/dataiku\python\reusing-code.md
# 3 QA generated from ../data/dataiku\python\spacy.md
# 1 QA generated from ../data/dataiku\python-api\index.md
# 3 QA generated from ../data/dataiku\R\dygraphs.md
# 0 QA generated from ../data/dataiku\R\ggplot2.md
# 3 QA generated from ../data/dataiku\R\ggvis.md
# 2 QA generated from ../data/dataiku\R\googlevis.md
# 3 QA generated from ../data/dataiku\R\index.md
# 2 QA generated from ../data/dataiku\R\packages.md
# 2 QA generated from ../data/dataiku\R\prophet.md
# 3 QA generated from ../data/dataiku\R\reusing-code.md
# 3 QA generated from ../data/dataiku\R\rstudio.md
# 3 QA generated from ../data/dataiku\R-api\authinfo.md
# 2 QA generated from ../data/dataiku\R-api\index.md
# 0 QA generated from ../data/dataiku\R-api\inside-usage.md
# 3 QA generated from ../data/dataiku\R-api\outside-usage.md
# 3 QA generated from ../data/dataiku\R-api\reference-doc.md
# 0 QA generated from ../data/dataiku\R-api\static_insights.md
# 3 QA generated from ../data/dataiku\release_notes\1.0.md
# 3 QA generated from ../data/dataiku\release_notes\1.1.md
# 3 QA generated from ../data/dataiku\release_notes\1.2.md
# 3 QA generated from ../data/dataiku\release_notes\1.3.md
# 3 QA generated from ../data/dataiku\release_notes\1.4.md
# 3 QA generated from ../data/dataiku\release_notes\10.0.md
# 3 QA generated from ../data/dataiku\release_notes\11.md
# 3 QA generated from ../data/dataiku\release_notes\12.md
# 3 QA generated from ../data/dataiku\release_notes\13.md
# ...
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_FSPROVIDER_ILLEGAL_PATH.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_FSPROVIDER_INVALID_CONFIG.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_FSPROVIDER_INVALID_FILE_NAME.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_FSPROVIDER_LOCAL_LIST_FAILED.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_FSPROVIDER_PATH_DOES_NOT_EXIST.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_FSPROVIDER_ROOT_PATH_DOES_NOT_EXIST.md
# 1 QA generated from ../data/dataiku\troubleshooting\errors\ERR_FSPROVIDER_SSH_CONNECTION_FAILED.md
# 1 QA generated from ../data/dataiku\troubleshooting\errors\ERR_FSPROVIDER_TOO_MANY_FILES.md
# 1 QA generated from ../data/dataiku\troubleshooting\errors\ERR_HIVE_HS2_CONNECTION_FAILED.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\ERR_HIVE_LEGACY_UNION_SUPPORT.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_JOB_INPUT_DATASET_NOT_READY_NO_FILES.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_LICENSING_TRIAL_INTERNAL_ERROR.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_LICENSING_TRIAL_STATUS_ERROR.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_METRIC_DATASET_COMPUTATION_FAILED.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_METRIC_ENGINE_RUN_FAILED.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_MISC_DISK_FULL.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\ERR_MISC_EIDB.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_MISC_ENOSPC.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_MISC_EOPENF.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\ERR_ML_MODEL_DETAILS_OVERFLOW.md
# 1 QA generated from ../data/dataiku\troubleshooting\errors\ERR_ML_VERTICA_NOT_SUPPORTED.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_NOT_USABLE_FOR_USER.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_OBJECT_OPERATION_NOT_AVAILABLE_FOR_TYPE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PLUGIN_CANNOT_LOAD.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PLUGIN_COMPONENT_NOT_INSTALLED.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PLUGIN_DEV_INVALID_COMPONENT_PARAMETER.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PLUGIN_DEV_INVALID_DEFINITION.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PLUGIN_INVALID_DEFINITION.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PLUGIN_MISSING_IN_CONTAINER_IMAGE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PLUGIN_NOT_INSTALLED.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PLUGIN_WITHOUT_CODEENV.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PLUGIN_WRONG_TYPE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PROJECT_INVALID_ARCHIVE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PROJECT_INVALID_PROJECT_KEY.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_PROJECT_UNKNOWN_PROJECT_KEY.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_CANNOT_CHANGE_ENGINE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_CANNOT_CHECK_SCHEMA_CONSISTENCY.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_CANNOT_CHECK_SCHEMA_CONSISTENCY_EXPENSIVE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_CANNOT_CHECK_SCHEMA_CONSISTENCY_NEEDS_BUILD.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_CANNOT_CHECK_SCHEMA_CONSISTENCY_ON_RECIPE_TYPE.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_CANNOT_CHECK_SCHEMA_CONSISTENCY_WITH_RECIPE_CONFIG.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_CANNOT_SPARK.md
# 1 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_CANNOT_USE_ENGINE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_ENGINE_NOT_DWH.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_INCONSISTENT_I_O.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_PDEP_UPDATE_REQUIRED.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_SPLIT_INVALID_COMPUTED_COLUMNS.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_RECIPE_SYNC_AWS_DIFFERENT_REGIONS.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SCENARIO_INVALID_STEP_CONFIG.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SECURITY_CRUD_INVALID_SETTINGS.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SECURITY_DECRYPTION_FAILED.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SECURITY_GROUP_EXISTS.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SECURITY_INVALID_NEW_PASSWORD.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SECURITY_INVALID_PASSWORD.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SECURITY_MUS_USER_UNMATCHED.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SECURITY_PATH_ESCAPE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SECURITY_USER_EXISTS.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SECURITY_WRONG_PASSWORD.md
# 3 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SPARK_FAILED_DRIVER_OOM.md
# 3 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SPARK_FAILED_TASK_OOM.md
# 3 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SPARK_FAILED_YARN_KILLED_MEMORY.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SPARK_PYSPARK_CODE_FAILED_UNSPECIFIED.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SPARK_SQL_LEGACY_UNION_SUPPORT.md
# 3 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SQL_CANNOT_LOAD_DRIVER.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SQL_DB_UNREACHABLE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SQL_IMPALA_MEMORYLIMIT.md
# 1 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SQL_POSTGRESQL_TOOMANYSESSIONS.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SQL_TABLE_NOT_FOUND.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SQL_VERTICA_TOOMANYROS.md
# 1 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SQL_VERTICA_TOOMANYSESSIONS.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\ERR_SYNAPSE_CSV_DELIMITER.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_TRANSACTION_FAILED_ENOSPC.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\ERR_TRANSACTION_GIT_COMMIT_FAILED.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\ERR_USER_ACTION_FORBIDDEN_BY_PROFILE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\index.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\INFO_RECIPE_IMPALA_POTENTIAL_FAST_PATH.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\INFO_RECIPE_POTENTIAL_FAST_PATH.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\undocumented-error.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_ACTIVITY_WAITING_K8S_CONTAINERSTARTING_CLOUD.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_ACTIVITY_WAITING_K8S_POD_PENDING_CLOUD.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_ACTIVITY_WAITING_K8S_QUOTA_EXCEEDED_CLOUD.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_ACTIVITY_WAITING_QUEUED_CLOUD.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_CLUSTERS_NONE_SELECTED_GLOBAL.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_CLUSTERS_NONE_SELECTED_PROJECT.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_CONNECTION_DATABRICKS_NO_AUTOFASTWRITE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_CONNECTION_HDFS_ACL_SUBDIRECTORY.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_CONNECTION_NO_HADOOP_INTERFACE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_CONNECTION_SNOWFLAKE_NO_AUTOFASTWRITE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_CONNECTION_SPARK_NO_GROUP_WITH_DETAILS_READ_ACCESS.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_FOLDER_CONNECTION_TYPE_ERROR.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_JOBS_MAX_OVER_MAX_ACTIVITIES.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_JOBS_MAX_TOO_HIGH.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_JOBS_NO_LIMIT.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_JVM_CONFIG_KERNEL_XMX_OVER_THRESHOLD.md
# 1 QA generated from ../data/dataiku\troubleshooting\errors\WARN_JVM_CONFIG_XMX_IN_RED_ZONE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_MISC_AUDIT_NO_LOG4J_LOCAL_TARGET.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_MISC_CODE_ENV_BUILTIN_MODIFIED.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_MISC_CODE_ENV_DEPRECATED_INTERPRETER.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_MISC_CODE_ENV_USES_PYSPARK.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_MISC_DISK_MOUNT_TYPE.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_MISC_DISK_NOEXEC_FLAG.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_MISC_DISK_ROTATIONAL.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_MISC_ENVVAR_SPECIAL_CHAR.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_MISC_EVENT_SERVER_NO_TARGET.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_MISC_JDBC_JARS_CONFLICT.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_MISC_LARGE_INTERNAL_DB.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_PROJECT_LARGE_JOB_HISTORY.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\WARN_PROJECT_LARGE_SCENARIO_HISTORY.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\WARN_PROJECT_LARGE_STREAMING_HISTORY.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_RECIPE_SPARK_INDIRECT_HDFS.md
# 1 QA generated from ../data/dataiku\troubleshooting\errors\WARN_RECIPE_SPARK_INDIRECT_S3.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_SECURITY_NO_CGROUPS.md
# 0 QA generated from ../data/dataiku\troubleshooting\errors\WARN_SECURITY_UIF_NOT_ENABLED.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\WARN_SPARK_K8S_KILLED_EXECUTORS.md
# 3 QA generated from ../data/dataiku\troubleshooting\errors\WARN_SPARK_MISSING_DRIVER_TO_EXECUTOR_CONNECTIVITY.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\WARN_SPARK_NON_DISTRIBUTED_READ.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\WARN_SPARK_NON_DISTRIBUTED_WRITE.md
# 1 QA generated from ../data/dataiku\troubleshooting\errors\WARN_SPARK_TASK_DISKFULL.md
# 3 QA generated from ../data/dataiku\troubleshooting\errors\WARN_SPARK_TASK_OOM.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\WARN_SPARK_UDFS_MAY_BE_BROKEN.md
# 2 QA generated from ../data/dataiku\troubleshooting\errors\WARN_SPARK_WITH_DATABRICKS_DATASET.md
# 0 QA generated from ../data/dataiku\troubleshooting\problems\cannot-connect-sql.md
# 3 QA generated from ../data/dataiku\troubleshooting\problems\cannot-login.md
# 0 QA generated from ../data/dataiku\troubleshooting\problems\crashes.md
# 3 QA generated from ../data/dataiku\troubleshooting\problems\does-not-start.md
# 3 QA generated from ../data/dataiku\troubleshooting\problems\index.md
# 2 QA generated from ../data/dataiku\troubleshooting\problems\job-fails.md
# 2 QA generated from ../data/dataiku\troubleshooting\problems\ml-train-fails.md
# 2 QA generated from ../data/dataiku\troubleshooting\problems\no-class-def-found.md
# 3 QA generated from ../data/dataiku\troubleshooting\problems\scenario-fails.md
# 3 QA generated from ../data/dataiku\troubleshooting\problems\tls-error.md
# 3 QA generated from ../data/dataiku\troubleshooting\problems\user-profile-issues.md
# 2 QA generated from ../data/dataiku\troubleshooting\problems\websockets.md
# 2 QA generated from ../data/dataiku\unstructured-data\audio\index.md
# 1 QA generated from ../data/dataiku\unstructured-data\image\index.md
# 0 QA generated from ../data/dataiku\unstructured-data\video\index.md
# 3 QA generated from ../data/dataiku\user-isolation\capabilities-summary.md
# 3 QA generated from ../data/dataiku\user-isolation\concepts.md
# 3 QA generated from ../data/dataiku\user-isolation\index.md
# 3 QA generated from ../data/dataiku\user-isolation\initial-setup.md
# 3 QA generated from ../data/dataiku\user-isolation\prerequisites-limitations.md
# 1 QA generated from ../data/dataiku\user-isolation\troubleshooting.md
# 1 QA generated from ../data/dataiku\user-isolation\advanced\hdfs-datasets.md
# 0 QA generated from ../data/dataiku\user-isolation\advanced\index.md
# 2 QA generated from ../data/dataiku\user-isolation\advanced\local-security.md
# 3 QA generated from ../data/dataiku\user-isolation\capabilities\hadoop-impersonation.md
# 0 QA generated from ../data/dataiku\user-isolation\capabilities\index.md
# 3 QA generated from ../data/dataiku\user-isolation\capabilities\kubernetes.md
# 0 QA generated from ../data/dataiku\user-isolation\capabilities\local-code.md
# 0 QA generated from ../data/dataiku\user-isolation\capabilities\oracle.md
# 3 QA generated from ../data/dataiku\user-isolation\reference-architectures\cloudera.md
# 1 QA generated from ../data/dataiku\user-isolation\reference-architectures\index.md
# 3 QA generated from ../data/dataiku\user-isolation\reference-architectures\kubernetes.md
# 0 QA generated from ../data/dataiku\user-isolation\reference-architectures\local-code-only.md
# Unterminated string starting at: line 3 column 14 (char 117)
# Error occured when generating QA from ../data/dataiku\variables\index.md
# 3 QA generated from ../data/dataiku\visualization\charts-basics.md
# 3 QA generated from ../data/dataiku\visualization\charts-maps.md
# 3 QA generated from ../data/dataiku\visualization\charts-other.md
# 3 QA generated from ../data/dataiku\visualization\charts-scatters.md
# 0 QA generated from ../data/dataiku\visualization\charts-tables.md
# 1 QA generated from ../data/dataiku\visualization\common.md
# 0 QA generated from ../data/dataiku\visualization\copy-paste.md
# 3 QA generated from ../data/dataiku\visualization\custom-aggregations.md
# 2 QA generated from ../data/dataiku\visualization\filter-settings.md
# 0 QA generated from ../data/dataiku\visualization\formatting.md
# 1 QA generated from ../data/dataiku\visualization\index.md
# 3 QA generated from ../data/dataiku\visualization\interface.md
# 3 QA generated from ../data/dataiku\visualization\palettes.md
# 2 QA generated from ../data/dataiku\visualization\reference-lines.md
# 3 QA generated from ../data/dataiku\visualization\sampling.md
# 3 QA generated from ../data/dataiku\visualization\third-party-bi-tools.md
# 0 QA generated from ../data/dataiku\webapps\bokeh.md
# 1 QA generated from ../data/dataiku\webapps\dash.md
# 2 QA generated from ../data/dataiku\webapps\dashboard.md
# 0 QA generated from ../data/dataiku\webapps\direct-access.md
# 3 QA generated from ../data/dataiku\webapps\index.md
# 3 QA generated from ../data/dataiku\webapps\introduction.md
# 0 QA generated from ../data/dataiku\webapps\kubernetes.md
# 2 QA generated from ../data/dataiku\webapps\public.md
# 3 QA generated from ../data/dataiku\webapps\security.md
# 0 QA generated from ../data/dataiku\webapps\shiny.md
# 0 QA generated from ../data/dataiku\webapps\standard.md
# 1 QA generated from ../data/dataiku\workspaces\index.md
# 2 QA generated from ../data/dataiku\workspaces\managing.md
# 2 QA generated from ../data/dataiku\workspaces\sharing-to-workspaces.md

# %%
len(qa_dataset)
# Out:
# 1978

# %%
qa_dataset = pd.DataFrame(qa_dataset)
qa_dataset.to_csv("../data/qa_dataset/dataiku_multiple_choice_qa.csv", index=False)

# %%
qa_dataset
# Out:
#                                                question  \
# 0     Which keyboard shortcut in Dataiku DSS is used...
# 1     In Dataiku DSS, which shortcut allows you to t...
# 2     What is the keyboard shortcut to validate a sc...
# 3     Which of the following APIs is NOT listed as a...
# 4     Which of the following sampling methods return...
# ...                                                 ...
# 1973  Which of the following objects can be shared i...
# 1974  Which of the following roles in a workspace ca...
# 1975  What permission is granted to everyone in a wo...
# 1976  How can a user share DSS objects into a Dataik...
# 1977  What happens to the visibility of a DSS object...
#
#                                                       A  \
# 0                                                 G + F
# 1                                         SHIFT + CLICK
# 2                                          CTRL + ENTER
# 3                                        Javascript API
# 4                                                  HEAD
# ...                                                 ...
# 1973                                       Applications
# 1974                                             Admins
# 1975                                              Write
# 1976  From the object’s Right Pane within the projec...
# 1977      It is visible only to the user who shared it.
#
#                                                       B  \
# 0                                                 G + D
# 1                                                 SPACE
# 2                                               ALT + A
# 3                                             Scala API
# 4                                                RANDOM
# ...                                                 ...
# 1973                                         Dashboards
# 1974                                       Contributors
# 1975                                               Read
# 1976  Only from the object’s Right Pane within the p...
# 1977  It is visible to all users in the workspace, r...
#
#                                                       C  \
# 0                                                 G + A
# 1                                          SHIFT + DRAG
# 2                                             SHIFT + V
# 3                                            Python API
# 4                                                  FULL
# ...                                                 ...
# 1973                                           Datasets
# 1974                                            Members
# 1975                                            Execute
# 1976     Only from the (+) button within the workspace.
# 1977  It is visible only to users with administrativ...
#
#                                                       D answer  \
# 0                                                 G + R      A
# 1                                                     Z      B
# 2                                              CTRL + F      A
# 3                                                 R API      C
# 4                                         RANDOM-COLUMN      A
# ...                                                 ...    ...
# 1973                                   All of the above      D
# 1974                                   All of the above      A
# 1975                                             Delete      B
# 1976  By sending an email to the workspace administr...      A
# 1977  It is visible only to users with editing permi...      B
#
#                                                    file
# 0                ../data/dataiku\accessibility\index.md
# 1                ../data/dataiku\accessibility\index.md
# 2                ../data/dataiku\accessibility\index.md
# 3                          ../data/dataiku\api\index.md
# 4                       ../data/dataiku\api\js\index.md
# ...                                                 ...
# 1973                ../data/dataiku\workspaces\index.md
# 1974             ../data/dataiku\workspaces\managing.md
# 1975             ../data/dataiku\workspaces\managing.md
# 1976  ../data/dataiku\workspaces\sharing-to-workspac...
# 1977  ../data/dataiku\workspaces\sharing-to-workspac...
#
# [1978 rows x 7 columns]
